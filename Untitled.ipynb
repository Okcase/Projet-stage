# %%
import pandas as pd
import geopandas as gpd

pd.set_option('display.max_rows', 348)

# %%
nom = pd.read_csv('Documents/Projet/ProjetStage/data/code_cultu_2019.csv', skiprows = 9, sep = ';')
nom
# Out:
#     Code_cultu                                            Libelle  \
# 0          ACA                   Autre culture non précisée (DOM)
# 1          AGR                                             Agrume
# 2          AIL                                                Ail
# 3          ANA                                             Ananas
# 4          ANE                                              Aneth
# 5          ANG                                          Angélique
# 6          ANI                                               Anis
# 7          ARA                                           Arachide
# 8          ART                                          Artichaut
# 9          AUB                                          Aubergine
# 10         AVH                                     Avoine d'hiver
# 11         AVO                                             Avocat
# 12         AVP                                Avoine de printemps
# ...

# %%
nom2 = pd.read_csv('Documents/Projet/ProjetStage/data/cultu2n73.csv', skiprows = 10, sep = ';').sort_values(by = ['Label_2019_V1', 'Libelle'])
nom2
# Out:
#     Code_cultu                                            Libelle  \
# 0          ACA                   Autre culture non précisée (DOM)
# 1          BAR                    Bardane [Asteracée bisannuelle]
# 4          CRN      Cornille [Fabacée - plante herbacée annuelle]
# 5          CUA                               Culture sous abattis
# 2          CID                   Cultures conduites en inter-rang
# 3          CIT                   Cultures conduites en inter-rang
# 6          DOL       Dolique [Fabacée - plante herbacée annuelle]
# 7          FNU      Fenugrec [Fabacée - plante herbacée annuelle]
# 8          GAI                                            Gaillet
# 11         PSY                                  Plantain psyllium
# 10         PSN                          Psyllium noir de Provence
# 9          PEP                                          Pépinière
# 12         VAL                                          Valériane
# ...

# %%
nom3 = pd.read_csv('Documents/Projet/ProjetStage/data/nomenclature_73c_2019.csv', skiprows = 12, sep = ';')
nom3
# Out:
#                                    LABEL_2019_V1      CODE9 CODE3  N2019  \
# 0                             Herbe prédominante  HERB_PRED   HER      1
# 1                             Blé tendre d’hiver  BLE_TEN_H   BTH      2
# 2                                           Maïs       MAIS   MIS      3
# 3                                   Orge d'hiver     ORGE_H   ORH      4
# 4                                  Colza d’hiver    COLZA_H   CZH      5
# 5                              Orge de printemps     ORGE_P   ORP      6
# 6                           Ligneux prédominants  LIGN_PRED   LGN      7
# 7                                      Tournesol  TOURNESOL   TRN      8
# 8                                          Vigne      VIGNE   VGN      9
# 9                                      Betterave  BETTERAVE   BTR     10
# 10                                       Luzerne    LUZERNE   LUZ     11
# 11                             Triticale d’hiver  TRITICA_H   TTH     12
# ...
